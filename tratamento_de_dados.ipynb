# %% [markdown]
# ### Bibliotecas

# %% [markdown]
# Adicionando as bibliotecas que serão utilizadas

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### DataFrames

# %%
df_spotify_youtube = pd.read_csv("../Projeto_ICD-Analise_de_Dados_do_Spotify_e_Youtube/Spotify_Youtube.csv")

# %% [markdown]
# Definindo o DataFrame "df_spotify_youtube_num" exclusivamente com dados numéricos e/ou não categóricos

# %%
numeric_columns = ['Danceability','Energy','Key','Loudness','Speechiness', 'Acousticness', 'Instrumentalness','Liveness','Valence','Tempo','Duration_ms', 'Views', 'Likes', 'Comments','Stream']
df_spotify_youtube_num = df_spotify_youtube[numeric_columns]
df_spotify_youtube_num
# Out:
#        Danceability  Energy   Key  Loudness  Speechiness  Acousticness  \
# 0             0.818   0.705   6.0    -6.679       0.1770      0.008360
# 1             0.676   0.703   8.0    -5.815       0.0302      0.086900
# 2             0.695   0.923   1.0    -3.930       0.0522      0.042500
# 3             0.689   0.739   2.0    -5.810       0.0260      0.000015
# 4             0.663   0.694  10.0    -8.627       0.1710      0.025300
# ...             ...     ...   ...       ...          ...           ...
# 20713         0.582   0.926   5.0    -6.344       0.0328      0.448000
# 20714         0.531   0.936   4.0    -1.786       0.1370      0.028000
# 20715         0.443   0.830   4.0    -4.679       0.0647      0.024300
# 20716         0.417   0.767   9.0    -4.004       0.4190      0.356000
# 20717         0.498   0.938   6.0    -4.543       0.1070      0.002770
#
#        Instrumentalness  Liveness  Valence    Tempo  Duration_ms        Views  \
# 0              0.002330    0.6130   0.7720  138.559     222640.0  693555221.0
# 1              0.000687    0.0463   0.8520   92.761     200173.0   72011645.0
# 2              0.046900    0.1160   0.5510  108.014     215150.0    8435055.0
# 3              0.509000    0.0640   0.5780  120.423     233867.0  211754952.0
# 4              0.000000    0.0698   0.5250  167.953     340920.0  618480958.0
# ...                 ...       ...      ...      ...          ...          ...
# 20713          0.000000    0.0839   0.6580   90.002      94667.0      71678.0
# 20714          0.000000    0.0923   0.6570  174.869     150857.0     164741.0
# 20715          0.000000    0.1540   0.4190  168.388     136842.0      35646.0
# 20716          0.018400    0.1080   0.5390  155.378     108387.0       6533.0
# 20717          0.911000    0.1360   0.0787  160.067     181500.0     158697.0
#
#            Likes  Comments        Stream
# 0      6220896.0  169907.0  1.040235e+09
# 1      1079128.0   31003.0  3.100837e+08
# 2       282142.0    7399.0  6.306347e+07
# 3      1788577.0   55229.0  4.346636e+08
# 4      6197318.0  155930.0  6.172597e+08
# ...          ...       ...           ...
# 20713     1113.0       0.0  9.227144e+06
# 20714     2019.0       0.0  1.089818e+07
# 20715      329.0       0.0  6.226110e+06
# 20716       88.0       0.0  6.873961e+06
# 20717     2484.0       0.0  5.695584e+06
#
# [20718 rows x 15 columns]

# %% [markdown]
# Definindo o DataFrame "df_spotify_youtube_ctg" exclusivamente com dados categóricos e/ou booleanos

# %%
not_numeric_columns = ['Artist', 'Url_spotify','Track','Album','Album_type','Uri','Url_youtube','Title','Channel', 'Description','Licensed','official_video']
df_spotify_youtube_ctg = df_spotify_youtube[not_numeric_columns]
df_spotify_youtube_ctg
# Out:
#             Artist                                        Url_spotify  \
# 0         Gorillaz  https://open.spotify.com/artist/3AA28KZvwAUcZu...
# 1         Gorillaz  https://open.spotify.com/artist/3AA28KZvwAUcZu...
# 2         Gorillaz  https://open.spotify.com/artist/3AA28KZvwAUcZu...
# 3         Gorillaz  https://open.spotify.com/artist/3AA28KZvwAUcZu...
# 4         Gorillaz  https://open.spotify.com/artist/3AA28KZvwAUcZu...
# ...            ...                                                ...
# 20713  SICK LEGEND  https://open.spotify.com/artist/3EYY5FwDkHEYLw...
# 20714  SICK LEGEND  https://open.spotify.com/artist/3EYY5FwDkHEYLw...
# 20715  SICK LEGEND  https://open.spotify.com/artist/3EYY5FwDkHEYLw...
# 20716  SICK LEGEND  https://open.spotify.com/artist/3EYY5FwDkHEYLw...
# 20717  SICK LEGEND  https://open.spotify.com/artist/3EYY5FwDkHEYLw...
#
#                                                Track  \
# 0                                     Feel Good Inc.
# 1                                    Rhinestone Eyes
# 2      New Gold (feat. Tame Impala and Bootie Brown)
# 3                                 On Melancholy Hill
# 4                                     Clint Eastwood
# ...                                              ...
# 20713                           JUST DANCE HARDSTYLE
# 20714                 SET FIRE TO THE RAIN HARDSTYLE
# 20715                      OUTSIDE HARDSTYLE SPED UP
# 20716                            ONLY GIRL HARDSTYLE
# 20717                             MISS YOU HARDSTYLE
#
#                                                Album Album_type  \
# 0                                         Demon Days      album
# 1                                      Plastic Beach      album
# 2      New Gold (feat. Tame Impala and Bootie Brown)     single
# 3                                      Plastic Beach      album
# 4                                           Gorillaz      album
# ...                                              ...        ...
# 20713                           JUST DANCE HARDSTYLE     single
# 20714                 SET FIRE TO THE RAIN HARDSTYLE     single
# 20715                      OUTSIDE HARDSTYLE SPED UP     single
# 20716                            ONLY GIRL HARDSTYLE     single
# 20717                             MISS YOU HARDSTYLE     single
#
#                                         Uri  \
# 0      spotify:track:0d28khcov6AiegSCpG5TuT
# 1      spotify:track:1foMv2HQwfQ2vntFf9HFeG
# 2      spotify:track:64dLd6rVqDLtkXFYrEUHIU
# 3      spotify:track:0q6LuUqGLUiCPP1cbdwFs3
# 4      spotify:track:7yMiX7n9SBvadzox8T5jzT
# ...                                     ...
# 20713  spotify:track:0RtcKQGyI4hr8FgFH1TuYG
# 20714  spotify:track:3rHvPA8lUnPBkaLyPOc0VV
# 20715  spotify:track:4jk00YxPtPbhvHJE9N4ddv
# 20716  spotify:track:5EyErbpsugWliX006eTDex
# 20717  spotify:track:6lOn0jz1QpjcWeXo1oMm0k
#
#                                        Url_youtube  \
# 0      https://www.youtube.com/watch?v=HyHNuVaZJ-k
# 1      https://www.youtube.com/watch?v=yYDmaexVHic
# 2      https://www.youtube.com/watch?v=qJa-VFwPpYA
# 3      https://www.youtube.com/watch?v=04mfKJWDSzI
# 4      https://www.youtube.com/watch?v=1V_xRb0x9aw
# ...                                            ...
# 20713  https://www.youtube.com/watch?v=5SHmKFKlNqI
# 20714  https://www.youtube.com/watch?v=ocTH6KxllDQ
# 20715  https://www.youtube.com/watch?v=5wFhE-HY0hg
# 20716  https://www.youtube.com/watch?v=VMFLbFRNCn0
# 20717  https://www.youtube.com/watch?v=zau0dckCFi0
#
#                                                    Title              Channel  \
# 0             Gorillaz - Feel Good Inc. (Official Video)             Gorillaz
# 1      Gorillaz - Rhinestone Eyes [Storyboard Film] (...             Gorillaz
# 2      Gorillaz - New Gold ft. Tame Impala & Bootie B...             Gorillaz
# 3         Gorillaz - On Melancholy Hill (Official Video)             Gorillaz
# 4             Gorillaz - Clint Eastwood (Official Video)             Gorillaz
# ...                                                  ...                  ...
# 20713                               JUST DANCE HARDSTYLE  SICK LEGEND - Topic
# 20714                     SET FIRE TO THE RAIN HARDSTYLE  SICK LEGEND - Topic
# 20715                          OUTSIDE HARDSTYLE SPED UP  SICK LEGEND - Topic
# 20716                                ONLY GIRL HARDSTYLE  SICK LEGEND - Topic
# 20717                                 MISS YOU HARDSTYLE  SICK LEGEND - Topic
#
#                                              Description Licensed  \
# 0      Official HD Video for Gorillaz' fantastic trac...     True
# 1      The official video for Gorillaz - Rhinestone E...     True
# 2      Gorillaz - New Gold ft. Tame Impala & Bootie B...     True
# 3      Follow Gorillaz online:\r\nhttp://gorillaz.com...     True
# 4      The official music video for Gorillaz - Clint ...     True
# ...                                                  ...      ...
# 20713  Provided to YouTube by Routenote\r\n\r\nJUST D...     True
# 20714  Provided to YouTube by Routenote\r\n\r\nSET FI...     True
# 20715  Provided to YouTube by Routenote\r\n\r\nOUTSID...     True
# 20716  Provided to YouTube by Routenote\r\n\r\nONLY G...     True
# 20717  Provided to YouTube by Routenote\r\n\r\nMISS Y...     True
#
#       official_video
# 0               True
# 1               True
# 2               True
# 3               True
# 4               True
# ...              ...
# 20713           True
# 20714           True
# 20715           True
# 20716           True
# 20717           True
#
# [20718 rows x 12 columns]

# %% [markdown]
# Definindo o DataFrame "df_spotify_youtube_ctp" exclusivamente com dados categóricos e/ou booleanos que sejam eficientemente plotáveis

# %%
ctp_columns = ['Album_type','Licensed','official_video']
df_spotify_youtube_ctp = df_spotify_youtube[ctp_columns]
df_spotify_youtube_ctp
# Out:
#       Album_type Licensed official_video
# 0          album     True           True
# 1          album     True           True
# 2         single     True           True
# 3          album     True           True
# 4          album     True           True
# ...          ...      ...            ...
# 20713     single     True           True
# 20714     single     True           True
# 20715     single     True           True
# 20716     single     True           True
# 20717     single     True           True
#
# [20718 rows x 3 columns]

# %% [markdown]
# ### Medidas de Centralidade e Dispersão - Dados Numéricos

# %% [markdown]
# Aplicando as medidas de centralidade e dispersão ao DataFrame "df_spotify_youtube_num" e suas respectivas colunas

# %% [markdown]
# #### Média

# %%
df_spotify_youtube_num.mean()
# Out:
# Danceability        6.197775e-01
# Energy              6.352503e-01
# Key                 5.300348e+00
# Loudness           -7.671680e+00
# Speechiness         9.645601e-02
# Acousticness        2.915353e-01
# Instrumentalness    5.596156e-02
# Liveness            1.935210e-01
# Valence             5.298533e-01
# Tempo               1.206383e+02
# Duration_ms         2.247176e+05
# Views               9.393782e+07
# Likes               6.633411e+05
# Comments            2.751899e+04
# Stream              1.359422e+08
# dtype: float64

# %% [markdown]
# #### Mediana

# %%
df_spotify_youtube_num.median()
# Out:
# Danceability        6.370000e-01
# Energy              6.660000e-01
# Key                 5.000000e+00
# Loudness           -6.536000e+00
# Speechiness         5.050000e-02
# Acousticness        1.930000e-01
# Instrumentalness    2.405000e-06
# Liveness            1.250000e-01
# Valence             5.370000e-01
# Tempo               1.199650e+02
# Duration_ms         2.132845e+05
# Views               1.450110e+07
# Likes               1.244810e+05
# Comments            3.277000e+03
# Stream              4.968298e+07
# dtype: float64

# %% [markdown]
# #### Moda

# %%
df_spotify_youtube_num.mode()
# Out:
#     Danceability  Energy  Key  Loudness  Speechiness  Acousticness  \
# 0          0.687   0.572  0.0    -7.818       0.0324         0.114
# 1            NaN     NaN  NaN       NaN          NaN           NaN
# 2            NaN     NaN  NaN       NaN          NaN           NaN
# 3            NaN     NaN  NaN       NaN          NaN           NaN
# 4            NaN     NaN  NaN       NaN          NaN           NaN
# 5            NaN     NaN  NaN       NaN          NaN           NaN
# 6            NaN     NaN  NaN       NaN          NaN           NaN
# 7            NaN     NaN  NaN       NaN          NaN           NaN
# 8            NaN     NaN  NaN       NaN          NaN           NaN
# 9            NaN     NaN  NaN       NaN          NaN           NaN
# 10           NaN     NaN  NaN       NaN          NaN           NaN
# 11           NaN     NaN  NaN       NaN          NaN           NaN
# 12           NaN     NaN  NaN       NaN          NaN           NaN
# 13           NaN     NaN  NaN       NaN          NaN           NaN
# 14           NaN     NaN  NaN       NaN          NaN           NaN
#
#     Instrumentalness  Liveness  Valence   Tempo  Duration_ms         Views  \
# 0                0.0      0.11    0.961  77.986     237467.0  6.639000e+03
# 1                NaN       NaN      NaN     NaN          NaN  2.191200e+04
# 2                NaN       NaN      NaN     NaN          NaN  4.333960e+05
# 3                NaN       NaN      NaN     NaN          NaN  3.020790e+06
# 4                NaN       NaN      NaN     NaN          NaN  3.877674e+06
# 5                NaN       NaN      NaN     NaN          NaN  8.266725e+06
# 6                NaN       NaN      NaN     NaN          NaN  1.309968e+07
# 7                NaN       NaN      NaN     NaN          NaN  2.588325e+07
# 8                NaN       NaN      NaN     NaN          NaN  7.623863e+07
# 9                NaN       NaN      NaN     NaN          NaN  9.870131e+07
# 10               NaN       NaN      NaN     NaN          NaN  9.934843e+07
# 11               NaN       NaN      NaN     NaN          NaN  1.029486e+08
# 12               NaN       NaN      NaN     NaN          NaN  3.122265e+08
# 13               NaN       NaN      NaN     NaN          NaN  6.414077e+08
# 14               NaN       NaN      NaN     NaN          NaN  1.012206e+09
#
#     Likes  Comments       Stream
# 0     0.0       0.0  169769959.0
# 1     NaN       NaN          NaN
# 2     NaN       NaN          NaN
# 3     NaN       NaN          NaN
# 4     NaN       NaN          NaN
# 5     NaN       NaN          NaN
# 6     NaN       NaN          NaN
# 7     NaN       NaN          NaN
# 8     NaN       NaN          NaN
# 9     NaN       NaN          NaN
# 10    NaN       NaN          NaN
# 11    NaN       NaN          NaN
# 12    NaN       NaN          NaN
# 13    NaN       NaN          NaN
# 14    NaN       NaN          NaN

# %% [markdown]
# #### Variância

# %%
df_spotify_youtube_num.var()
# Out:
# Danceability        2.731496e-02
# Energy              4.585886e-02
# Key                 1.279098e+01
# Loudness            2.146236e+01
# Speechiness         1.253505e-02
# Acousticness        8.196701e-02
# Instrumentalness    3.735021e-02
# Liveness            2.840266e-02
# Valence             6.024119e-02
# Tempo               8.749183e+02
# Duration_ms         1.557268e+10
# Views               7.542950e+16
# Likes               3.201681e+12
# Comments            3.733965e+10
# Stream              5.960047e+16
# dtype: float64

# %% [markdown]
# #### Desvio Padrão

# %%
df_spotify_youtube_num.std()
# Out:
# Danceability        1.652724e-01
# Energy              2.141468e-01
# Key                 3.576449e+00
# Loudness            4.632749e+00
# Speechiness         1.119600e-01
# Acousticness        2.862988e-01
# Instrumentalness    1.932620e-01
# Liveness            1.685309e-01
# Valence             2.454408e-01
# Tempo               2.957902e+01
# Duration_ms         1.247905e+05
# Views               2.746443e+08
# Likes               1.789324e+06
# Comments            1.932347e+05
# Stream              2.441321e+08
# dtype: float64

# %% [markdown]
# ### Medidas de Centralidade e Dispersão - Dados Categóricos

# %% [markdown]
# Aplicando as medidas de centralidade e dispersão ao DataFrame "df_spotify_youtube_ctg" e suas respectivas colunas

# %% [markdown]
# #### Moda

# %%
df_spotify_youtube_ctg.mode()
# Out:
#               Artist                                        Url_spotify  \
# 0               $NOT  https://open.spotify.com/artist/003f4bk13c6Q3g...
# 1        $uicideboy$  https://open.spotify.com/artist/00FQb4jTyendYW...
# 2           (G)I-DLE  https://open.spotify.com/artist/00XhexlJEXQstH...
# 3             *NSYNC  https://open.spotify.com/artist/00me4Ke1LsvMxt...
# 4          070 Shake  https://open.spotify.com/artist/00sCATpEvwH48a...
# ...              ...                                                ...
# 2044       will.i.am  https://open.spotify.com/artist/7y97mc3bZRFXzT...
# 2045  Ángela Aguilar  https://open.spotify.com/artist/7yQrcdkLdBAkV7...
# 2046            Ñejo  https://open.spotify.com/artist/7ygNQCdpQWW7iS...
# 2047      Ñengo Flow  https://open.spotify.com/artist/7z5WFjZAIYejWy...
# 2048        Øneheart  https://open.spotify.com/artist/7zpvy5B9gb5Kpr...
#
#                                           Track          Album Album_type  \
# 0     El Ultimo Adiós - Varios Artistas Version  Greatest Hits      album
# 1                                           NaN            NaN        NaN
# 2                                           NaN            NaN        NaN
# 3                                           NaN            NaN        NaN
# 4                                           NaN            NaN        NaN
# ...                                         ...            ...        ...
# 2044                                        NaN            NaN        NaN
# 2045                                        NaN            NaN        NaN
# 2046                                        NaN            NaN        NaN
# 2047                                        NaN            NaN        NaN
# 2048                                        NaN            NaN        NaN
#
#                                        Uri  \
# 0     spotify:track:0tzixmHNQfE6S6SirSToxW
# 1                                      NaN
# 2                                      NaN
# 3                                      NaN
# 4                                      NaN
# ...                                    ...
# 2044                                   NaN
# 2045                                   NaN
# 2046                                   NaN
# 2047                                   NaN
# 2048                                   NaN
#
#                                       Url_youtube  \
# 0     https://www.youtube.com/watch?v=GqOvxbFLwjY
# 1                                             NaN
# 2                                             NaN
# 3                                             NaN
# 4                                             NaN
# ...                                           ...
# 2044                                          NaN
# 2045                                          NaN
# 2046                                          NaN
# 2047                                          NaN
# 2048                                          NaN
#
#                                                   Title   Channel Description  \
# 0     Color Esperanza 2020 - Various Artists (Offici...  T-Series
# 1                                                   NaN       NaN         NaN
# 2                                                   NaN       NaN         NaN
# 3                                                   NaN       NaN         NaN
# 4                                                   NaN       NaN         NaN
# ...                                                 ...       ...         ...
# 2044                                                NaN       NaN         NaN
# 2045                                                NaN       NaN         NaN
# 2046                                                NaN       NaN         NaN
# 2047                                                NaN       NaN         NaN
# 2048                                                NaN       NaN         NaN
#
#      Licensed official_video
# 0        True           True
# 1         NaN            NaN
# 2         NaN            NaN
# 3         NaN            NaN
# 4         NaN            NaN
# ...       ...            ...
# 2044      NaN            NaN
# 2045      NaN            NaN
# 2046      NaN            NaN
# 2047      NaN            NaN
# 2048      NaN            NaN
#
# [2049 rows x 12 columns]

# %% [markdown]
# ### Boxplot

# %% [markdown]
# Construindo o gráfico boxplot das variáveis pertencentes às colunas do DataFrame "df_spotify_youtube_num"

# %%
plt.figure(figsize=(10, 5))
sns.set_palette('pastel')
sns.boxplot(data= df_spotify_youtube_num[['Danceability','Energy','Speechiness','Acousticness','Liveness','Valence']])
plt.show()

# %%
plt.figure(figsize=(10, 5))
plt.yscale('log')
sns.boxplot(data= df_spotify_youtube_num[['Views','Likes','Comments']])
plt.show()

# %%
plt.figure(figsize=(10, 5))
plt.yscale('log')
sns.boxplot(data= df_spotify_youtube_num[['Stream']])
plt.show()

# %%
plt.figure(figsize=(10, 5))
plt.yscale('log')
sns.boxplot(data= df_spotify_youtube_num[['Instrumentalness']])
plt.show()

# %%
plt.figure(figsize=(10, 5))
plt.yscale('log')
sns.boxplot(data= df_spotify_youtube_num[['Duration_ms']])
plt.show()

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data= df_spotify_youtube_num[['Loudness']])
plt.show()

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data= df_spotify_youtube_num[['Key']])
plt.show()

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data= df_spotify_youtube_num[['Tempo']])
plt.show()

# %% [markdown]
# ### Gráfico - Dados Categóricos

# %% [markdown]
# Construindo o gráfico de barras das variáveis pertencentes às colunas do DataFrame "df_spotify_youtube_ctp"

# %% [markdown]
# #### Coluna 'Album_type'

# %%
counts = df_spotify_youtube_ctp['Album_type'].value_counts()
counts = counts.rename_axis('Album_type').rename(index={'compilation': 'Others'})
sns.barplot(x=counts.index,y=counts.values)
plt.xlabel('Album Type')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# #### Coluna 'Lincensed'

# %%
counts = df_spotify_youtube_ctp['Licensed'].value_counts()
sns.barplot(x=counts.index,y=counts.values)
plt.xlabel('Licensed')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# #### Coluna 'official_video'

# %%
counts = df_spotify_youtube_ctg['official_video'].value_counts()
sns.barplot(x=counts.index,y=counts.values)
plt.xlabel('official_video')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# ### Gráfico de Dispersão

# %% [markdown]
# Construindo gráficos de dispersão das variáveis pertencentes às colunas do DataFrame "df_spotify_youtube_num"

# %% [markdown]
# #### Views, Likes e Comments

# %%
sns.scatterplot(data=df_spotify_youtube_num,x='Views',y='Likes',size='Comments',alpha=0.5)
# Out:
# <Axes: xlabel='Views', ylabel='Likes'>

# %% [markdown]
# #### Loudness e Energy

# %%
sns.scatterplot(data=df_spotify_youtube_num,x='Loudness',y='Energy',alpha=0.5)
# Out:
# <Axes: xlabel='Loudness', ylabel='Energy'>

# %% [markdown]
# #### Acousticness e Energy

# %%
sns.scatterplot(data=df_spotify_youtube_num,x='Acousticness',y='Energy',alpha=0.5)
# Out:
# <Axes: xlabel='Acousticness', ylabel='Energy'>

# %% [markdown]
# #### Danceability e Tempo

# %%
sns.scatterplot(data=df_spotify_youtube_num,x='Danceability',y='Tempo',alpha=0.5)
# Out:
# <Axes: xlabel='Danceability', ylabel='Tempo'>

# %% [markdown]
# #### Instrumentalness e Loudness

# %%
sns.scatterplot(data=df_spotify_youtube_num,x='Instrumentalness',y='Loudness',alpha=0.5)
# Out:
# <Axes: xlabel='Instrumentalness', ylabel='Loudness'>

# %% [markdown]
# ### Gráfico de Barras

# %% [markdown]
# Construindo gráficos de barras das variáveis pertencentes as colunas do DataFrame "df_spotify_youtube"

# %% [markdown]
# #### Album Type e Stream

# %%
df_spotify_youtube = pd.read_csv("../Projeto_ICD-Analise_de_Dados_do_Spotify_e_Youtube/Spotify_Youtube.csv")
df_spotify_youtube['Album_type'] = df_spotify_youtube['Album_type'].replace('compilation', 'others')
sns.barplot(data=df_spotify_youtube,x="Album_type",y="Stream",color='#ADD8E6')
a=sns.barplot(data=df_spotify_youtube,x="Album_type",y="Stream",color='#ADD8E6')
a.set(xlabel='Album type',ylabel='Stream')
# Out:
# [Text(0.5, 0, 'Album type'), Text(0, 0.5, 'Stream')]

# %% [markdown]
# ####  Official_video e Views

# %%
df_spotify_youtube = pd.read_csv("../Projeto_ICD-Analise_de_Dados_do_Spotify_e_Youtube/Spotify_Youtube.csv")
sns.barplot(data=df_spotify_youtube,x="official_video",y="Views",color='#ADD8E6')
a=sns.barplot(data=df_spotify_youtube,x="official_video",y="Views",color='#ADD8E6')
a.set(xlabel='official video[0 or 1]',ylabel='Views')
# Out:
# [Text(0.5, 0, 'official video[0 or 1]'), Text(0, 0.5, 'Views')]

# %% [markdown]
# #### Official_video e Likes

# %%
df_spotify_youtube = pd.read_csv("../Projeto_ICD-Analise_de_Dados_do_Spotify_e_Youtube/Spotify_Youtube.csv")
sns.barplot(data=df_spotify_youtube,x="official_video",y="Likes",color='#ADD8E6')
a=sns.barplot(data=df_spotify_youtube,x="official_video",y="Likes",color='#ADD8E6')
a.set(xlabel='official video[0 or 1]',ylabel='Likes')
# Out:
# [Text(0.5, 0, 'official video[0 or 1]'), Text(0, 0.5, 'Likes')]

# %% [markdown]
# #### Official_video e Comments

# %%
df_spotify_youtube = pd.read_csv("../Projeto_ICD-Analise_de_Dados_do_Spotify_e_Youtube/Spotify_Youtube.csv")
sns.barplot(data=df_spotify_youtube,x="official_video",y="Likes",color='#ADD8E6')
a=sns.barplot(data=df_spotify_youtube,x="official_video",y="Likes",color='#ADD8E6')
a.set(xlabel='official video[0 or 1]',ylabel='Likes')
# Out:
# [Text(0.5, 0, 'official video[0 or 1]'), Text(0, 0.5, 'Likes')]

# %%
### Matriz Correlação

# %%
Construindo gráficos de barras das variáveis pertencentes as colunas do DataFrame "df_spotify_youtube"

# %%
df_spotify_youtube = pd.read_csv("../Projeto_ICD-Analise_de_Dados_do_Spotify_e_Youtube/Spotify_Youtube.csv")
correlacao_matriz = df_spotify_youtube [['Danceability', 'Energy', 'Key', 'Loudness', 'Speechiness']].corr()
plt.figure(figsize=(10, 8))
sns.heatmap(correlacao_matriz, annot=True, cmap='coolwarm', color='#ADD8E6')
plt.title('Matriz Correlação')
plt.show()

# %%
df_spotify_youtube = pd.read_csv("../Projeto_ICD-Analise_de_Dados_do_Spotify_e_Youtube/Spotify_Youtube.csv")
correlacao_matriz = df_spotify_youtube [['Acousticness', 'Instrumentalness', 'Liveness', 'Valence', 'Tempo']].corr()
plt.figure(figsize=(10, 8))
sns.heatmap(correlacao_matriz, annot=True, cmap='coolwarm')
plt.title('Matriz Correlação')
plt.show()

# %%
df_spotify_youtube = pd.read_csv("../Projeto_ICD-Analise_de_Dados_do_Spotify_e_Youtube/Spotify_Youtube.csv")
correlacao_matriz = df_spotify_youtube [['Duration_ms', 'Views', 'Likes', 'Comments', 'Stream']].corr()
plt.figure(figsize=(10, 8))
sns.heatmap(correlacao_matriz, annot=True, cmap='coolwarm')
plt.title('Matriz Correlação')
plt.show()

# %%
### Gráfico - Histograma

# %%
#### Coluna 'Album_type'

# %%
df_spotify_youtube = pd.read_csv("../Projeto_ICD-Analise_de_Dados_do_Spotify_e_Youtube/Spotify_Youtube.csv")
counts = df_spotify_youtube['Album_type'].value_counts()
counts = counts.rename_axis('Album_type').rename(index={'compilation': 'Others'})
sns.displot(data=df_spotify_youtube, x='Album_type', bins=10, kde=False)
plt.xlabel('Album_type')
plt.ylabel('Count')
plt.show()

# %%
#### Coluna 'Licensed'

# %%
df_spotify_youtube = pd.read_csv("../Projeto_ICD-Analise_de_Dados_do_Spotify_e_Youtube/Spotify_Youtube.csv")
counts = df_spotify_youtube['Licensed'].value_counts()
counts = counts.rename_axis('Licensed').rename(index={'compilation': 'Others'})
sns.displot(data=df_spotify_youtube, x='Licensed', bins=3, kde=False)
plt.xlabel('Licensed')
plt.ylabel('Count')
plt.show()

# %%
#### Coluna 'official_video'

# %%
df_spotify_youtube = pd.read_csv("../Projeto_ICD-Analise_de_Dados_do_Spotify_e_Youtube/Spotify_Youtube.csv")
counts = df_spotify_youtube['official_video'].value_counts()
counts = counts.rename_axis('official_video').rename(index={'compilation': 'Others'})
sns.displot(data=df_spotify_youtube, x='official_video', bins=3, kde=False)
plt.xlabel('official_video')
plt.ylabel('Count')
plt.show()
